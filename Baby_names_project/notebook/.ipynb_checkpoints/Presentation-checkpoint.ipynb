# %%
import pandas as pd

# %%
df = pd.read_csv('../data/all_years_baby_names.csv')

# %%
df.head()
# Out:
#         name gender  frequency  year
# 0       Mary      F       7065  1880
# 1       Anna      F       2604  1880
# 2       Emma      F       2003  1880
# 3  Elizabeth      F       1939  1880
# 4     Minnie      F       1746  1880

# %%
df_Emma = df[df['name']== 'Emma']

# %%
df_Emma
# Out:
#          name gender  frequency  year
# 2        Emma      F       2003  1880
# 1554     Emma      M         10  1880
# 2002     Emma      F       2034  1881
# 3555     Emma      M          9  1881
# 3936     Emma      F       2303  1882
# ...       ...    ...        ...   ...
# 1952188  Emma      M          9  2018
# 1957933  Emma      F      17194  2019
# 1983225  Emma      M         11  2019
# 1990042  Emma      F      15680  2020
# 2012606  Emma      M         18  2020
#
# [258 rows x 4 columns]

# %%
df_Emma_F = df_Emma[(df_Emma['gender'] == 'F') & (df_Emma['year']>1985)]

# %%
df_Emma_F
# Out:
#          name gender  frequency  year
# 981867   Emma      F       1258  1986
# 1002495  Emma      F       1587  1987
# 1023893  Emma      F       1793  1988
# 1046255  Emma      F       1938  1989
# 1070013  Emma      F       2420  1990
# 1094725  Emma      F       2595  1991
# 1119819  Emma      F       3212  1992
# 1145227  Emma      F       4108  1993
# 1171189  Emma      F       4765  1994
# 1197179  Emma      F       5050  1995
# 1223247  Emma      F       6146  1996
# 1249656  Emma      F       7749  1997
# 1276615  Emma      F      10448  1998
# 1304519  Emma      F      11746  1999
# 1333076  Emma      F      12559  2000
# 1362848  Emma      F      13325  2001
# 1393120  Emma      F      16554  2002
# 1423690  Emma      F      22714  2003
# 1454884  Emma      F      21617  2004
# 1486942  Emma      F      20353  2005
# 1519501  Emma      F      19126  2006
# 1553604  Emma      F      18381  2007
# 1588568  Emma      F      18823  2008
# 1623663  Emma      F      17908  2009
# ...

# %%
df_Emma_F.to_csv('../data/df_Emma_F.csv')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (12,8))
plt.plot(df_Emma_F['year'], df_Emma_F['frequency'], label = 'Track Emma over time', color = "skyblue", marker= 'o', linestyle = '-')
plt.grid(True, linestyle='--', alpha=0.7)
plt.title("Name Frequency of Emma (1985-2020)")
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend()

# %%
df_Joey = df[df['name']== 'Joey']

# %%
df_Joey_M = df_Joey[(df_Joey['gender'] == 'M') & (df_Joey['year']>1985)]

# %%
plt.figure(figsize = (12,8))
plt.plot(df_Joey_M['year'], df_Joey_M['frequency'], label = 'Track Joey over time', color = "royalblue", marker = 'o', linestyle = '-')
plt.grid(True, linestyle='--', alpha=0.7)
plt.title("Name Frequency of Joey (1985-2020)")
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend()

# Add a background color to the plot area for better contrast
plt.gca().set_facecolor('#f0f0f0')

# %%
df_Ross = df[df['name']== 'Ross']

# %%
df_Ross_M = df_Ross[(df_Ross['gender'] == 'M') & (df_Ross['year']>1985)]

# %%
plt.figure(figsize = (12,8))
plt.plot(df_Ross_M['year'], df_Ross_M['frequency'], label = 'Track Ross over time', color = "navy", marker = 'd', linestyle= '--')

plt.grid(True, linestyle='--', alpha=0.7)
# Customize tick marks on the x-axis for better readability
plt.gca().set_facecolor('#f0f0f0')
plt.legend(shadow =True)
plt.title("Name Frequency of Ross (1985-2020)")
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.legend()

plt.xticks(range(1985, 2021, 10), rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x14ab542ab50>,
# ...
#  [Text(1985, 0, '1985'),
#   Text(1995, 0, '1995'),
#   Text(2005, 0, '2005'),
#   Text(2015, 0, '2015')])

# %%
df_Phoebe = df[df['name']== 'Phoebe']

# %%
df_Phoebe
# Out:
#            name gender  frequency  year
# 216      Phoebe      F         50  1880
# 2232     Phoebe      F         46  1881
# 4152     Phoebe      F         62  1882
# 6282     Phoebe      F         66  1883
# 8363     Phoebe      F         75  1884
# ...         ...    ...        ...   ...
# 1860295  Phoebe      F       1034  2016
# 1893358  Phoebe      F       1021  2017
# 1926030  Phoebe      F       1025  2018
# 1958220  Phoebe      F       1149  2019
# 1990294  Phoebe      F       1179  2020
#
# [142 rows x 4 columns]

# %%
df_Phoebe_F = df_Phoebe[(df_Phoebe['gender'] == 'F') & (df_Phoebe['year']>1985)]

# %%
plt.figure(figsize = (10,8))
plt.plot(df_Phoebe_F['year'], df_Phoebe_F['frequency'], label = 'Track Phoebe over time', marker ='D', color = "purple", )
plt.title("Name Frequency of Phoebe (1985-2020)")
plt.gca().set_facecolor('#f0f0f0')
plt.grid(True, linestyle='--', color ='blue')
plt.legend()

# Set the background color of the plot area to black
plt.gca().set_facecolor('black')


plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_Monica = df[df['name']== 'Monica']

# %%
df_Monica_F = df_Monica[(df_Monica['gender'] == 'F') & (df_Monica['year']>1985)]

# %%
plt.figure(figsize = (10,8))
plt.plot(df_Monica_F['year'], df_Monica_F['frequency'], label = 'Track Monica over time', color = "yellow", marker = 'o' )
plt.title("Name Frequency of Monica (1985-2020)")
plt.grid()
plt.legend()
plt.gca().set_facecolor('green')
plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_Rachel = df[df['name']== 'Rachel']

# %%
df_Rachel_F = df_Rachel[(df_Rachel['gender'] == 'F') & (df_Rachel['year']>1985)]

# %%
plt.figure(figsize = (10,8))
plt.plot(df_Rachel_F['year'], df_Rachel_F['frequency'], label = 'Track Rachel over time', color = "blue", linestyle = '-')
plt.title("Name Frequency of Rachel(1985-2020)")
plt.grid()
plt.legend()
plt.gca().set_facecolor('skyblue')
plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df_Chandler = df[df['name']== 'Chandler']

# %%
df_Chandler_M = df_Chandler[(df_Chandler['gender'] == 'M') & (df_Chandler['year']>1985)]

# %%
plt.figure(figsize = (10,8))
plt.plot(df_Chandler_M['year'], df_Chandler_M['frequency'], label = 'Track Chandler over time', color = "blue", marker ='s', linestyle = '--')
plt.title("Name Frequency of Chandler (1985-2020)")
plt.gca().set_facecolor('purple')
plt.grid()
plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
