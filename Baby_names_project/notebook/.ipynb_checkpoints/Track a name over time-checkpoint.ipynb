# %%
#Using any of the single name over time dataframes created in Filtering DataFrames
#Create a line plot with the years and the (relative) frequencies of a specific name

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/all_years_baby_names.csv')

# %%
Marina_filter = df['name']== "Marina"
df_Marina = df.loc[Marina_filter].copy()

df_Marina.head()

df_Marina['relative_frequency'] = df_Marina['frequency']/df_Marina['frequency'].sum()

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\marinabishay\miniconda3\lib\site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marinabishay\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\marinabishay\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (10,8))
plt.plot(df_Marina['year'], df_Marina['relative_frequency'], label = 'Track Marina over time', color = "blue")
plt.title("Name Frequency (1880-2020)")
plt.xlabel('Year')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
def parse_dataset(year):
    #opening a text file and returning a dataframe for one year 
    #year = input(f'Please input year')
    df = pd.read_csv(f'../data/data/names/yob{year}.txt', names = ["name", "gender", "frequency"])
    return df

# %%
df_2000 = parse_dataset(2000)

# %%
df_2000['namelength']=df_2000['name'].apply(len)

# %%
df_2000
# Out:
#           name gender  frequency  namelength
# 0        Emily      F      25957           5
# 1       Hannah      F      23085           6
# 2      Madison      F      19968           7
# 3       Ashley      F      17998           6
# 4        Sarah      F      17712           5
# ...        ...    ...        ...         ...
# 29771     Zeph      M          5           4
# 29772    Zeven      M          5           5
# 29773    Ziggy      M          5           5
# 29774       Zo      M          5           2
# 29775    Zyier      M          5           5
#
# [29776 rows x 4 columns]

# %%
plt.figure(figsize = (10,6))
plt.hist(df_2000['namelength'], label=' Name Length distribution', bins=range(1, max(df_2000['namelength'])), color = 'blue')
plt.title('Name Length Distribution')
plt.xlabel('length of the name')
plt.ylabel('Frequency')
plt.legend()

plt.show()

# %% [markdown]
# #### Plot the average length of name over time

# %%
df
# Out:
#               name gender  frequency    year
# 0             Mary      F       7065  1880.0
# 1             Anna      F       2604  1880.0
# 2             Emma      F       2003  1880.0
# 3        Elizabeth      F       1939  1880.0
# 4           Minnie      F       1746  1880.0
# ...            ...    ...        ...     ...
# 2021553     Zykier      M          5  2020.0
# 2021554      Zylus      M          5  2020.0
# 2021555     Zymari      M          5  2020.0
# 2021556        Zyn      M          5  2020.0
# 2021557      Zyran      M          5  2020.0
#
# [2021558 rows x 4 columns]

# %%
average_lengths = []

# %%
for year in range(1880, 2021):
    df_year = parse_dataset(year)
    average_length = df_year['name'].apply(len).mean()
    average_lengths.append(average_length)

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1880, 2021), average_lengths, marker='o')
plt.title('Average Length of Names Over Time (1880-2020)')
plt.xlabel('Year')
plt.ylabel('Average Name Length')
plt.grid(True)
plt.show()
